# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 2. Imports
import os
import pandas as pd

# %%
# 3. Path to your CICIoT2023 folder (which contains all 171 CSV files)
CICIOT_PATH = "/content/drive/MyDrive/Datasets/CICIoT2023/"
OTHER_DRIVE_PATH = "/content/drive/MyDrive/Shared with me/IDS_DATASETS"

# %%
ciciot_files = [f for f in os.listdir(CICIOT_PATH) if f.endswith(".csv")]
print("Total CICIoT2023 CSV files:", len(ciciot_files))
print(ciciot_files[:5])
# Out:
# Total CICIoT2023 CSV files: 140
# ['part-00000-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00002-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00001-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00003-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00005-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv']

# %%
# 5. (Optional but recommended) Check if all CSVs have the same columns
base_cols = set(pd.read_csv(os.path.join(CICIOT_PATH, ciciot_files[0]), nrows=1).columns)

for f in ciciot_files:
    cols = set(pd.read_csv(os.path.join(CICIOT_PATH, f), nrows=1).columns)
    if cols != base_cols:
        print("Column mismatch found in:", f)

print("Column consistency check completed.")
# Out:
# Column consistency check completed.

# %%
# 6. Merge all 171 CSV files into one big CSV (memory-safe using chunks)
CICIOT_OUTPUT = "/content/CICIoT2023_FULL.csv"

first = True
for f in ciciot_files:
    file_path = os.path.join(CICIOT_PATH, f)
    print("Merging:", f)

    for chunk in pd.read_csv(file_path, chunksize=100000):
        if first:
            chunk.to_csv(CICIOT_OUTPUT, index=False, mode="w")
            first = False
        else:
            chunk.to_csv(CICIOT_OUTPUT, index=False, mode="a", header=False)

print("CICIoT2023 merged file created at:", CICIOT_OUTPUT)
# Out:
# Merging: part-00000-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00002-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00001-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00003-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00005-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00004-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00008-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00007-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00006-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00009-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00010-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00011-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00013-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00012-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00016-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00014-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00015-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00018-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00019-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00017-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00021-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00020-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00024-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00022-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00023-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00025-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00026-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00027-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00029-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00028-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00030-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00031-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00032-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00033-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00034-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00035-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00037-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00038-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00036-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00039-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00040-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00041-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00042-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00044-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00043-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00045-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00046-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00047-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00050-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00049-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00048-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00052-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00051-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00053-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00054-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00056-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00055-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00057-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00058-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00059-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00061-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00060-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00062-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00063-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00064-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00065-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00066-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00067-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00068-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00069-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00071-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00070-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00073-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00074-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00072-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00075-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00077-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00076-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00078-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00079-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00080-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00081-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00082-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00083-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00086-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00084-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00085-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00088-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00087-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00089-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00091-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00090-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00093-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00092-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00094-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00095-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00097-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00096-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00098-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00099-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00101-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00102-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00100-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00103-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00104-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00105-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00108-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00106-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00107-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00109-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00110-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00112-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00111-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00113-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00114-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00117-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00115-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00116-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00118-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00119-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00120-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00122-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00121-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00124-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00123-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00126-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00125-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00129-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00127-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00128-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00130-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00133-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00131-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00132-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00135-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00134-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00136-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00137-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00138-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Merging: part-00139-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# CICIoT2023 merged file created at: /content/CICIoT2023_FULL.csv

# %%
import os

file_path = "/content/CICIoT2023_FULL.csv"
size_bytes = os.path.getsize(file_path)

size_mb = size_bytes / (1024 * 1024)
size_gb = size_mb / 1024

print(f"File size: {size_mb:.2f} MB")
print(f"File size: {size_gb:.2f} GB")
# Out:
# File size: 10669.46 MB
# File size: 10.42 GB

# %%
import pandas as pd

input_file = "/content/CICIoT2023_FULL.csv"
output_file = "/content/CICIoT2023_SMALL.csv"

chunksize = 200_000
sample_fraction = 0.02   # 2%

first = True
for chunk in pd.read_csv(input_file, chunksize=chunksize):
    sampled = chunk.sample(frac=sample_fraction, random_state=42)

    if first:
        sampled.to_csv(output_file, index=False, mode="w")
        first = False
    else:
        sampled.to_csv(output_file, index=False, mode="a", header=False)

print("Reduced dataset created:", output_file)
# Out:
# Reduced dataset created: /content/CICIoT2023_SMALL.csv

# %%
import pandas as pd

# Load merged dataset
df = pd.read_csv("/content/CICIoT2023_SMALL.csv")

# Number of rows and columns
print("Shape of dataset (rows, columns):", df.shape)

# Total number of features (excluding label)
if "Label" in df.columns:
    print("Total columns:", len(df.columns))
    print("Total features (excluding Label):", len(df.columns) - 1)
else:
    print("Total columns:", len(df.columns))

# Column names (features)
print("\nColumns / Features:")
for col in df.columns:
    print(col)

# Quick info
print("\nDataset Info:")
print(df.info())

# View first 5 rows
print("\nSample data:")
df.head()
# Out:
# Shape of dataset (rows, columns): (759515, 47)
# Total columns: 47
#
# Columns / Features:
# flow_duration
# Header_Length
# Protocol Type
# Duration
# Rate
# Srate
# Drate
# fin_flag_number
# syn_flag_number
# rst_flag_number
# psh_flag_number
# ack_flag_number
# ece_flag_number
# cwr_flag_number
# ack_count
# syn_count
# fin_count
# urg_count
# rst_count
# HTTP
# HTTPS
# DNS
# Telnet
# SMTP
# SSH
# IRC
# TCP
# UDP
# DHCP
# ARP
# ICMP
# IPv
# LLC
# Tot sum
# Min
# Max
# AVG
# Std
# Tot size
# IAT
# Number
# Magnitue
# Radius
# Covariance
# Variance
# Weight
# label
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 759515 entries, 0 to 759514
# Data columns (total 47 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   flow_duration    759515 non-null  float64
#  1   Header_Length    759515 non-null  float64
#  2   Protocol Type    759515 non-null  float64
#  3   Duration         759515 non-null  float64
#  4   Rate             759515 non-null  float64
#  5   Srate            759515 non-null  float64
#  6   Drate            759515 non-null  float64
#  7   fin_flag_number  759515 non-null  float64
#  8   syn_flag_number  759515 non-null  float64
#  9   rst_flag_number  759515 non-null  float64
#  10  psh_flag_number  759515 non-null  float64
#  11  ack_flag_number  759515 non-null  float64
#  12  ece_flag_number  759515 non-null  float64
#  13  cwr_flag_number  759515 non-null  float64
#  14  ack_count        759515 non-null  float64
#  15  syn_count        759515 non-null  float64
#  16  fin_count        759515 non-null  float64
#  17  urg_count        759515 non-null  float64
#  18  rst_count        759515 non-null  float64
#  19  HTTP             759515 non-null  float64
#  20  HTTPS            759515 non-null  float64
#  21  DNS              759515 non-null  float64
#  22  Telnet           759515 non-null  float64
#  23  SMTP             759515 non-null  float64
#  24  SSH              759515 non-null  float64
#  25  IRC              759515 non-null  float64
#  26  TCP              759515 non-null  float64
#  27  UDP              759515 non-null  float64
#  28  DHCP             759515 non-null  float64
#  29  ARP              759515 non-null  float64
#  30  ICMP             759515 non-null  float64
#  31  IPv              759515 non-null  float64
#  32  LLC              759515 non-null  float64
#  33  Tot sum          759515 non-null  float64
#  34  Min              759515 non-null  float64
#  35  Max              759515 non-null  float64
#  36  AVG              759515 non-null  float64
#  37  Std              759515 non-null  float64
#  38  Tot size         759515 non-null  float64
#  39  IAT              759515 non-null  float64
#  40  Number           759515 non-null  float64
#  41  Magnitue         759515 non-null  float64
#  42  Radius           759515 non-null  float64
#  43  Covariance       759515 non-null  float64
#  44  Variance         759515 non-null  float64
#  45  Weight           759515 non-null  float64
#  46  label            759515 non-null  object
# dtypes: float64(46), object(1)
# memory usage: 272.3+ MB
# None
#
# Sample data:
#    flow_duration  Header_Length  Protocol Type  Duration         Rate  \
# 0       0.000000          54.00            6.0     64.00     2.215436
# 1       0.000000           0.00            1.0     64.00     4.239848
# 2       0.041094       14025.00           17.0     64.00  7679.553787
# 3       0.001894          55.56            6.0     63.63     9.699986
# 4       0.716513          75.60            6.0     64.00     1.116023
#
#          Srate  Drate  fin_flag_number  syn_flag_number  rst_flag_number  ...  \
# 0     2.215436    0.0              0.0              1.0              0.0  ...
# 1     4.239848    0.0              0.0              0.0              0.0  ...
# 2  7679.553787    0.0              0.0              0.0              0.0  ...
# 3     9.699986    0.0              0.0              0.0              0.0  ...
# 4     1.116023    0.0              0.0              1.0              0.0  ...
#
#         Std  Tot size           IAT  Number   Magnitue    Radius  Covariance  \
# 0  0.000000     54.00  8.297355e+07     9.5  10.392305  0.000000    0.000000
# 1  0.000000     42.00  8.314939e+07     9.5   9.165151  0.000000    0.000000
# 2  0.000000     50.00  8.309854e+07     9.5  10.000000  0.000000    0.000000
# 3  0.192336     54.24  8.307639e+07     9.5  10.397587  0.273495    0.853467
# 4  0.000000     54.00  8.336220e+07     9.5  10.392305  0.000000    0.000000
#
#    Variance  Weight                    label
# 0      0.00  141.55            DoS-SYN_Flood
# 1      0.00  141.55          DDoS-ICMP_Flood
# 2      0.00  141.55           DDoS-UDP_Flood
# 3      0.05  141.55           DDoS-TCP_Flood
# 4      0.00  141.55  DDoS-SynonymousIP_Flood
#
# [5 rows x 47 columns]

# %%
from google.colab import files
files.download("/content/CICIoT2023_SMALL.csv")
